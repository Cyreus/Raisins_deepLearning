# %%
import pandas as pd

import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)
cervical = pd.read_excel("/content/Raisin_Dataset.xlsx") 
warnings.filterwarnings("ignore")

# %%
pip install pycaret
pip install NumPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: NumPy in /usr/local/lib/python3.10/dist-packages (1.22.4)

# %%
from pycaret.classification import *
from pycaret.regression import *

# %%
cervical.head()
predictors=cervical
predictors=predictors.dropna()

predictors.head()
target = cervical['Class']

from pyod.models.pca import PCA
from locale import normalize
clf1 = setup(data = predictors, 
             target = "Class",
             normalize=False)
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
best = compare_models()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea0b6" class="dataframe">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
print(best)
# Out:
# []

# %%
df = pd.read_excel("/content/Raisin_Dataset.xlsx")
df
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# 2    0.637613   1208.575  Kecimen
# 3    0.699599    844.162  Kecimen
# 4    0.792772   1073.251  Kecimen
# ..        ...        ...      ...
# 895  0.668793   1129.072    Besni
# 896  0.636476   1214.252    Besni
# 897  0.741099   1292.828    Besni
# 898  0.658798   1258.548    Besni
# 899  0.632020   1272.862    Besni
#
# [900 rows x 8 columns]

# %%
pip install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-visualizer
#   Downloading keras_visualizer-3.1.2-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from keras-visualizer) (0.20.1)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-3.1.2

# %%
from keras_visualizer import visualizer

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from keras.models.cloning import sequential
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Dense

plt.figure(figsize=(12,7))
sns.countplot(x='Class', data=df)
plt.show()

labelencoder = LabelEncoder()

df["Class"] = labelencoder.fit_transform(df['Class'])
df.head()
df.info()


df["Class"].unique()
df.head(10)
from sklearn.preprocessing import StandardScaler,LabelBinarizer
X = df.drop(columns='Class') 
y = df['Class']
y=LabelBinarizer().fit_transform(y)

train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.20)
model=Sequential()

model.add(Dense(units = 10, input_dim=(7), activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(3, activation='relu')) 
model.add(Dense(1, activation='softmax'))
model.summary()
visualizer(model, file_name='graph', file_format="png", view=False, settings=None)

model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

cikis=model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(5, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 144/144 - 3s - loss: 0.0000e+00 - accuracy: 0.4931 - 3s/epoch - 24ms/step
# Epoch 2/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 249ms/epoch - 2ms/step
# Epoch 3/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 215ms/epoch - 1ms/step
# Epoch 4/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
# Epoch 5/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 214ms/epoch - 1ms/step
# Epoch 6/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 7/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 226ms/epoch - 2ms/step
# Epoch 8/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 9/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 213ms/epoch - 1ms/step
# Epoch 10/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 299ms/epoch - 2ms/step
# Epoch 11/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 311ms/epoch - 2ms/step
# Epoch 12/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 296ms/epoch - 2ms/step
# Epoch 13/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 315ms/epoch - 2ms/step
# Epoch 14/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 312ms/epoch - 2ms/step
# Epoch 15/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 300ms/epoch - 2ms/step
# Epoch 16/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 308ms/epoch - 2ms/step
# Epoch 17/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 293ms/epoch - 2ms/step
# Epoch 18/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 269ms/epoch - 2ms/step
# Epoch 19/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 20/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 204ms/epoch - 1ms/step
# Epoch 21/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 22/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 218ms/epoch - 2ms/step
# Epoch 23/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 24/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 25/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 215ms/epoch - 1ms/step
# Epoch 26/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 27/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 216ms/epoch - 2ms/step
# Epoch 28/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 224ms/epoch - 2ms/step
# Epoch 29/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 30/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 209ms/epoch - 1ms/step
# Epoch 31/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 204ms/epoch - 1ms/step
# Epoch 32/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
# Epoch 33/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 34/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 35/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 36/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 209ms/epoch - 1ms/step
# Epoch 37/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 220ms/epoch - 2ms/step
# Epoch 38/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 39/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 208ms/epoch - 1ms/step
# Epoch 40/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 41/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 42/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 43/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 44/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 213ms/epoch - 1ms/step
# Epoch 45/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 209ms/epoch - 1ms/step
# Epoch 46/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 214ms/epoch - 1ms/step
# Epoch 47/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 48/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 204ms/epoch - 1ms/step
# Epoch 49/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 217ms/epoch - 2ms/step
# Epoch 50/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 217ms/epoch - 2ms/step
# Epoch 51/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 221ms/epoch - 2ms/step
# Epoch 52/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 206ms/epoch - 1ms/step
# Epoch 53/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 206ms/epoch - 1ms/step
# Epoch 54/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 205ms/epoch - 1ms/step
# Epoch 55/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 219ms/epoch - 2ms/step
# Epoch 56/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 206ms/epoch - 1ms/step
# Epoch 57/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 58/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 59/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 205ms/epoch - 1ms/step
# Epoch 60/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 213ms/epoch - 1ms/step
# Epoch 61/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 216ms/epoch - 2ms/step
# Epoch 62/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 208ms/epoch - 1ms/step
# Epoch 63/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 216ms/epoch - 1ms/step
# Epoch 64/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
# Epoch 65/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 284ms/epoch - 2ms/step
# Epoch 66/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 301ms/epoch - 2ms/step
# Epoch 67/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 312ms/epoch - 2ms/step
# Epoch 68/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 301ms/epoch - 2ms/step
# Epoch 69/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 301ms/epoch - 2ms/step
# Epoch 70/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 303ms/epoch - 2ms/step
# Epoch 71/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 293ms/epoch - 2ms/step
# Epoch 72/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 315ms/epoch - 2ms/step
# Epoch 73/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 287ms/epoch - 2ms/step
# Epoch 74/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 215ms/epoch - 1ms/step
# Epoch 75/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 203ms/epoch - 1ms/step
# Epoch 76/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 77/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 205ms/epoch - 1ms/step
# Epoch 78/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 79/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 202ms/epoch - 1ms/step
# Epoch 80/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 81/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 216ms/epoch - 2ms/step
# Epoch 82/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 83/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 84/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 210ms/epoch - 1ms/step
# Epoch 85/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 217ms/epoch - 2ms/step
# Epoch 86/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
# Epoch 87/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 88/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 89/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 90/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 217ms/epoch - 2ms/step
# Epoch 91/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 205ms/epoch - 1ms/step
# Epoch 92/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 211ms/epoch - 1ms/step
# Epoch 93/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 204ms/epoch - 1ms/step
# Epoch 94/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 207ms/epoch - 1ms/step
# Epoch 95/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 213ms/epoch - 1ms/step
# Epoch 96/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
# Epoch 97/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 206ms/epoch - 1ms/step
# Epoch 98/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 214ms/epoch - 1ms/step
# Epoch 99/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 208ms/epoch - 1ms/step
# Epoch 100/100
# 144/144 - 0s - loss: 0.0000e+00 - accuracy: 0.4931 - 212ms/epoch - 1ms/step
